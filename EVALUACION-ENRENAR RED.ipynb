# %%
import matplotlib.pyplot as plt
import numpy as np 
w=np.array([0.11848282362811335,0.4527569581471502])
teta=0.040893273201404234
alpha=0.7
X=np.array([[-3.91294592, 0.01533953], [-2.3532511, -0.32128855], [-0.88738799, -0.2598815], [2.32858428, 2.08764605]])

r=[1, 1, 0, 0]
lon=len(r) 
res=0
con=True


xp1=[-3.91294592, 0.01533953]
xp2= [-2.3532511, -0.32128855]
xp3=[-0.88738799, -0.2598815]
xp4=[2.32858428, 2.08764605]

funx1= lambda: -teta/w[0]
funx2= lambda:-teta/w[1]
x=np.array([funx1(),0])
y=np.array([0,funx2()])
errores=[]

m=(y[1]-y[0])/(x[1]-x[0])

fu=lambda num: m*(num-x[0])
li=np.array(range(-10,10))
cont=1
while(con):
    print("--------------------------------------------")
    print("PASO: ",cont)
    for i in range(lon):
        print("X1: ", x)
        print("X2: ", y)
        plt.title('Gráfica: '+str(i))
        plt.axhline(y=0,color="red")
        plt.axvline(x=0,color="red")
        plt.plot(xp1,xp2,"o",color="red")
        plt.plot(xp3,xp4,"x",color="blue")
        plt.plot(li,fu(li))
        plt.grid(True)
        plt.show()
        print("Patrón ",(i+1) , " = (", X[i][0],",",X[i][1],")")
        
        val=X[i][0]*w[0]+X[i][1]*w[1]+teta
        print("VALOR OBTENIDO > ",val)
        if val >=0:
            res=1
            print("Esperado: ",r[i])
            print("Obtenido: ",res)
        else:
            res=0
            print("Esperado: ",r[i])
            print("Obtenido: ",res)
        if(res!=r[i]):
            er=r[i]-res
            print("Error: ", er)
            errores.append(er)
            aux=np.array([X[i][0],X[i][1]])
            print("Peso Anterior: ",w)
            w=w+(alpha*er*aux)
            print("Nuevo peso: ",w)
            print("Viejo Bias: ",teta)
            teta=teta+alpha*er
            print("Bías: ",teta)
            x=np.array([funx1(),0])
            y=np.array([0,funx2()])
            m=(y[1]-y[0])/(x[1]-x[0])
        else:
            errores.append(0)
    print("FIN PASO: ", cont)
    print("--------------------------------------------")
    cont+=1
    if errores == r2:
        con=False
        print("Fin")
        print("Ecuación Solución: y=",m,"x ",y[1] )
    else:
        errores=[]
# Out:
# --------------------------------------------
# PASO:  1
# X1:  [-0.34514094  0.        ]
# X2:  [ 0.         -0.09032058]
# Patrón  1  = ( -3.91294592 , 0.01533953 )
# VALOR OBTENIDO >  -0.4157785291620945
# Esperado:  1
# Obtenido:  0
# Error:  1
# Peso Anterior:  [0.11848282 0.45275696]
# Nuevo peso:  [-2.62057932  0.46349463]
# Viejo Bias:  0.040893273201404234
# Bías:  0.7408932732014042
# X1:  [0.28272118 0.        ]
# X2:  [ 0.         -1.59849376]
# Patrón  2  = ( -2.3532511 , -0.32128855 )
# VALOR OBTENIDO >  6.758858924172322
# Esperado:  1
# Obtenido:  1
# X1:  [0.28272118 0.        ]
# X2:  [ 0.         -1.59849376]
# Patrón  3  = ( -0.88738799 , -0.2598815 )
# VALOR OBTENIDO >  2.9459102094770726
# Esperado:  0
# Obtenido:  1
# Error:  -1
# Peso Anterior:  [-2.62057932  0.46349463]
# Nuevo peso:  [-1.99940773  0.64541168]
# Viejo Bias:  0.7408932732014042
# Bías:  0.040893273201404234
# X1:  [0.02045269 0.        ]
# X2:  [ 0.         -0.06335998]
# Patrón  4  = ( 2.32858428 , 2.08764605 )
# VALOR OBTENIDO >  -3.267504987471879
# Esperado:  0
# Obtenido:  0
# FIN PASO:  1
# --------------------------------------------
# --------------------------------------------
# PASO:  2
# X1:  [0.02045269 0.        ]
# X2:  [ 0.         -0.06335998]
# Patrón  1  = ( -3.91294592 , 0.01533953 )
# VALOR OBTENIDO >  7.874367894252326
# Esperado:  1
# Obtenido:  1
# X1:  [0.02045269 0.        ]
# X2:  [ 0.         -0.06335998]
# Patrón  2  = ( -2.3532511 , -0.32128855 )
# VALOR OBTENIDO >  4.538638324441542
# Esperado:  1
# Obtenido:  1
# X1:  [0.02045269 0.        ]
# X2:  [ 0.         -0.06335998]
# Patrón  3  = ( -0.88738799 , -0.2598815 )
# VALOR OBTENIDO >  1.64741312229013
# Esperado:  0
# Obtenido:  1
# Error:  -1
# Peso Anterior:  [-1.99940773  0.64541168]
# Nuevo peso:  [-1.37823613  0.82732873]
# Viejo Bias:  0.040893273201404234
# Bías:  -0.6591067267985957
# X1:  [-0.47822482  0.        ]
# X2:  [0.         0.79666849]
# Patrón  4  = ( 2.32858428 , 2.08764605 )
# VALOR OBTENIDO >  -2.1412761699693683
# Esperado:  0
# Obtenido:  0
# FIN PASO:  2
# --------------------------------------------
# --------------------------------------------
# PASO:  3
# X1:  [-0.47822482  0.        ]
# X2:  [0.         0.79666849]
# Patrón  1  = ( -3.91294592 , 0.01533953 )
# VALOR OBTENIDO >  4.746547565849061
# Esperado:  1
# Obtenido:  1
# X1:  [-0.47822482  0.        ]
# X2:  [0.         0.79666849]
# Patrón  2  = ( -2.3532511 , -0.32128855 )
# VALOR OBTENIDO >  2.318417724710762
# Esperado:  1
# Obtenido:  1
# X1:  [-0.47822482  0.        ]
# X2:  [0.         0.79666849]
# Patrón  3  = ( -0.88738799 , -0.2598815 )
# VALOR OBTENIDO >  0.3489160351031868
# Esperado:  0
# Obtenido:  1
# Error:  -1
# Peso Anterior:  [-1.37823613  0.82732873]
# Nuevo peso:  [-0.75706454  1.00924578]
# Viejo Bias:  -0.6591067267985957
# Bías:  -1.3591067267985957
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  4  = ( 2.32858428 , 2.08764605 )
# VALOR OBTENIDO >  -1.015047352466858
# Esperado:  0
# Obtenido:  0
# FIN PASO:  3
# --------------------------------------------
# --------------------------------------------
# PASO:  4
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  1  = ( -3.91294592 , 0.01533953 )
# VALOR OBTENIDO >  1.618727237445797
# Esperado:  1
# Obtenido:  1
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  2  = ( -2.3532511 , -0.32128855 )
# VALOR OBTENIDO >  0.09819712497998201
# Esperado:  1
# Obtenido:  1
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  3  = ( -0.88738799 , -0.2598815 )
# VALOR OBTENIDO >  -0.9495810520837562
# Esperado:  0
# Obtenido:  0
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  4  = ( 2.32858428 , 2.08764605 )
# VALOR OBTENIDO >  -1.015047352466858
# Esperado:  0
# Obtenido:  0
# FIN PASO:  4
# --------------------------------------------
# --------------------------------------------
# PASO:  5
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  1  = ( -3.91294592 , 0.01533953 )
# VALOR OBTENIDO >  1.618727237445797
# Esperado:  1
# Obtenido:  1
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  2  = ( -2.3532511 , -0.32128855 )
# VALOR OBTENIDO >  0.09819712497998201
# Esperado:  1
# Obtenido:  1
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  3  = ( -0.88738799 , -0.2598815 )
# VALOR OBTENIDO >  -0.9495810520837562
# Esperado:  0
# Obtenido:  0
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  4  = ( 2.32858428 , 2.08764605 )
# VALOR OBTENIDO >  -1.015047352466858
# Esperado:  0
# Obtenido:  0
# FIN PASO:  5
# --------------------------------------------
# --------------------------------------------
# PASO:  6
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  1  = ( -3.91294592 , 0.01533953 )
# VALOR OBTENIDO >  1.618727237445797
# Esperado:  1
# Obtenido:  1
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  2  = ( -2.3532511 , -0.32128855 )
# VALOR OBTENIDO >  0.09819712497998201
# Esperado:  1
# Obtenido:  1
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  3  = ( -0.88738799 , -0.2598815 )
# VALOR OBTENIDO >  -0.9495810520837562
# Esperado:  0
# Obtenido:  0
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  4  = ( 2.32858428 , 2.08764605 )
# VALOR OBTENIDO >  -1.015047352466858
# Esperado:  0
# Obtenido:  0
# FIN PASO:  6
# --------------------------------------------
# --------------------------------------------
# PASO:  7
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  1  = ( -3.91294592 , 0.01533953 )
# VALOR OBTENIDO >  1.618727237445797
# Esperado:  1
# Obtenido:  1
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  2  = ( -2.3532511 , -0.32128855 )
# VALOR OBTENIDO >  0.09819712497998201
# Esperado:  1
# Obtenido:  1
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  3  = ( -0.88738799 , -0.2598815 )
# VALOR OBTENIDO >  -0.9495810520837562
# Esperado:  0
# Obtenido:  0
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# Patrón  4  = ( 2.32858428 , 2.08764605 )
# VALOR OBTENIDO >  -1.015047352466858
# Esperado:  0
# Obtenido:  0
# FIN PASO:  7
# --------------------------------------------
# --------------------------------------------
# PASO:  8
# X1:  [-1.79523231  0.        ]
# X2:  [0.         1.34665584]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-cddd0ffe4e00> in <module>
#      41         plt.plot(li,fu(li))
#      42         plt.grid(True)
# ---> 43         plt.show()
#      44         print("Patrón ",(i+1) , " = (", X[i][0],",",X[i][1],")")
#      45
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     179         # the background is transparent
#     180         ticksLight = _is_light([label.get_color()
# --> 181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#     183                                 for label in axis.get_ticklabels()])
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
# --> 183                                 for label in axis.get_ticklabels()])
#     184         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     185             # there are one or more tick labels, all with the same lightness
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1294         if minor:
#    1295             return self.get_minorticklabels()
# -> 1296         return self.get_majorticklabels()
#    1297
#    1298     def get_majorticklines(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1250     def get_majorticklabels(self):
#    1251         'Return a list of Text instances for the major ticklabels.'
# -> 1252         ticks = self.get_major_ticks()
#    1253         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1254         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1409         while len(self.majorTicks) < numticks:
#    1410             # Update the new tick label properties from the old.
# -> 1411             tick = self._get_tick(major=True)
#    1412             self.majorTicks.append(tick)
#    1413             tick.gridline.set_visible(self._gridOnMajor)
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1931         else:
#    1932             tick_kw = self._minor_tick_kw
# -> 1933         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1934
#    1935     def _get_label(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#      82         size is the tick size in points
#      83         """
# ---> 84         martist.Artist.__init__(self)
#      85
#      86         if gridOn is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in __init__(self)
#      94         self.eventson = False  # fire events only if eventson
#      95         self._oid = 0  # an observer id
# ---> 96         self._propobservers = {}  # a dict from oids to funcs
#      97         try:
#      98             self.axes = None
#
# KeyboardInterrupt:
